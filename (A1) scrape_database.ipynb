# %% [markdown]
# # Scrape RateMyTeacher.com
#
# In this notebook we can scrape the entirety of RateMyTeacher.com. This process consists of a layered approach. The first step is to download a map of all the reviews on RateMyTeacher.com

# %%
import multiprocessing
import pandas as pd
import os 

import rmt_scraper

# During dev, reload the module after any alterations
#from importlib import reload 
#rmt_scraper = reload(rmt_scraper)

# find the number of processors 
processors = multiprocessing.cpu_count() - 1

# %% [markdown]
# Instantiate the scraper for the US by feeding it the US homepage for rmt. RMT contains reviews from many english speaking countries. The homepage for any of these may be submitted via this scraper. Once the scraper is instantiated it will automatically populate all the available states (or country equivalent) for the submitted homepage.

# %%
# instantiate the scraper to scrape the U.S. database
scraper = rmt_scraper.rmt_scraper('https://www.ratemyteachers.com')

# load the last instance of the database 
scraper.load_sitemap()

# load the school description database so it can be built out as well
scraper.load_schooldb()
print('\nFind the sitemap under "scraper.reference_database" and the school database has been saved in "scraper.school_database"')
# Out:
# Scraper setup for https://www.ratemyteachers.com
# Populating states
#
# Find the sitemap under "scraper.reference_database" and the school database has been saved in "scraper.school_database"

# %% [markdown]
# You can review the states by typing *scraper.states* to view the states attribute.
#
# ## Generate Site Map
# <br>**THIS STEP GENERATES THE <font color = red>"reference_database.csv"</font> AND <font color=red>"school_database.csv"</font> DATASETS, SKIP IF YOU PLAN ON USING THE EXISTING VERSIONS IN THE "data" DIRECTORY**</font>
#
# <br>In this next step we use the *refresh_database* method to generate a ".csv" file with database (site map) containing the nested fields ***State > City > School > Teacher*** where Teacher is the most specific webpage. Reviews can then be collected from each teacher page.
#
# **Scraping the sitemap can take a few hours and fail due to connection interruptions, but all is not lost!!!** The *refresh_database* method automatically saves everything that was scraped to a ".csv" file in the data directory called "reference_database.csv" and a complimentary dataset containing school descriptions to a dataset called "school_database.csv". If you rerun the scraper (even if you've instantiated a new one) it will automatically look for these files in the data directory and ask you if you want to load it, you can also submit a custom pandas DataFrame object to *refresh_database* for the scraper to build on.
#
# Note that using the *refresh_database* command will generate this site map for all available states in *scraper.states*. To view use a subset of states simply set the *scraper.states* attribute equal to a subset of itself. To regain the full state list without re-instantiating the scraper use *scraper.get_states(scraper.home_url)*.
#
# ### Threaded Scraping
#
# The scraper rmt_scraper object supports multi-threaded scraping which can be used to significantly speed up the process. Use the workers argument in the *refresh_database* method to indicate the number of CPUs to use. Feed it *(workers = -1)* to use all available cores. If you want to stop this code block at any time I suggest you disconnect the internet, it will be faster than interrupting the kernel and won't risk losing you your data in a crash.

# %% [markdown]
# **Site Map Dataset** - The columns represent the nested levels Teacher < School < City < State

# %%
# you don't need to scrape this if the reference database already has everything you need
#%%time  # uncomment to time 

# use the command below to scrape, you can scrape it from its last point with the use_existing option. 
#scraper.refresh_database(workers = processors, use_existing = scraper.reference_database, use_schools = school_descs) #uncomment to scrape

# remove any scrap variables from the dataset and display a sample of each of the datasets collected so far 
scraper.site_map = scraper.site_map.drop([c for c in scraper.site_map.columns if 'Unnamed' in c], 1)
print('Site Map:')
scraper.site_map.sample(10).head(5)
# Out:
# Site Map:
#                               City                                  School  \
# 228754            /georgia/conyers     /rockdale-county-high-school/6086-s
# 147130            /florida/orlando       /timber-creek-high-school/40034-s
# 593106  /new-york/long-island-city  /long-island-city-high-school/156849-s
# 169822           /florida/sarasota         /mcintosh-middle-school/45945-s
# 786846               /texas/spring      /the-woodlands-high-school/19038-s
#
#                                           State                    Teacher
# 228754   https://www.ratemyteachers.com/Georgia      /mary-lyles/6926695-t
# 147130   https://www.ratemyteachers.com/Florida  /victoria-velez/7473759-t
# 593106  https://www.ratemyteachers.com/New-York         /disanto/4117381-t
# 169822   https://www.ratemyteachers.com/Florida    /ralph-jarvis/1045200-t
# 786846     https://www.ratemyteachers.com/Texas   /donna-brawner/4309963-t

# %% [markdown]
# **School Description Dataset** - Descriptions of each school, can be merged with the Site Map Dataset by School

# %%
# do the same for the school descriptions dataset 
scraper.school_database = scraper.school_database.drop([c for c in scraper.school_database.columns if 'Unnamed' in c], 1)
print('Here is a sample description:\n %s' % str(scraper.school_database.loc[0,'school_description']).strip())
print('\nSchool Descriptions:')
scraper.school_database.sample(10).head(5)
# Out:
# Here is a sample description:
#  Abbott Loop Elementary School is a public elementary school located in Anchorage, Alaska and part of Anchorage School District.
#
# School Descriptions:
#                                        School  \
# 3771     /st-gregory-the-great-school/39923-s
# 15198    /highland-elementary-school/290015-s
# 6209           /pivot-charter-school/272203-s
# 25283                /collin-college/141032-s
# 24249  /white-rock-elementary-school/220745-s
#
#                                                  address  \
# 3771       85 Great Plain Rd, Danbury, Connecticut 06811
# 15198  1915 Buffalo Lake Rd, Sanford, North Carolina ...
# 6209       8129 N Pine Island Rd, Tamarac, Florida 33321
# 25283              3452 Spur 399, Mc Kinney, Texas 75069
# 24249              9229 Chiswell Rd, Dallas, Texas 75238
#
#                       gender         phone  \
# 3771                     NaN  203-748-1217
# 15198  428 Male | 419 Female  919-499-2200
# 6209                     NaN  954-720-3001
# 25283      0 Male | 0 Female  972-548-6790
# 24249                    NaN  469-593-2700
#
#                                       school_description  \
# 3771    St Gregory The Great School is a private midd...
# 15198   Highland Elementary School is a public elemen...
# 6209    Pivot Charter School is a public charter high...
# 25283   Collin College is located in Mc Kinney, Texas...
# 24249   White Rock Elementary School is a public elem...
#
#                      student  \
# 3771                     NaN
# 15198  847 Students Enrolled
# 6209                     NaN
# 25283    0 Students Enrolled
# 24249                    NaN
#
#                                                  website
# 3771                                                 NaN
# 15198  http://www.harnett.k12.nc.us/Schools/highland/...
# 6209         http://pivotcharterschoolfortlauderdale.com
# 25283                             http://www.collin.edu/
# 24249  http://www.richardson.k12.tx.us/administration...

# %% [markdown]
# ## Scraping Reviews
#
# We use the site map to guide the review scraper. We can srape by State, School, City or Teacher and use the *for_values* option to scrape for certain States, Schools, Cities or Teachers respectively (default by City). The scraped data will be saved as .pickle files at the level selected (e.g. 1 .pickle per City). The level cannot be 'Teacher'.
#
# **Note** that this can take a very long time depending on how much you want to scrape. You may run into similar connection issues as above where the server cuts off requests for a time or the connection is persistently interrupted. In these cases simply rerun the command. The *get_reviews_by* detects the files that have already been collected and collects those that are missing. Use the *overwrite* option to ignore existing files.

# %%
# scrape reviews 
#scraper.get_reviews_by(by = 'City', workers = processors, prefix = 'US ')

# show the files in the data folder
files = [f for f in list(os.walk(os.getcwd() + '/data'))[0][2] if 'US' in f]
files
# Out:
# ['US Alabama alabaster.csv',
#  'US Alabama albertville.csv',
#  'US Alabama alexander-city.csv',
#  'US Alabama alexandria.csv',
#  'US Alabama anniston.csv',
#  'US Alabama arab.csv',
#  'US Alabama ardmore.csv',
#  'US Alabama ashford.csv',
#  'US Alabama athens.csv',
#  'US Alabama auburn.csv',
#  'US Alabama birmingham.csv',
#  'US Alabama carbon-hill.csv',
#  'US Alabama citronelle.csv',
#  'US Alabama clanton.csv',
#  'US Alabama cleveland.csv',
#  'US Alabama cullman.csv',
#  'US Alabama dadeville.csv',
#  'US Alabama daphne.csv',
#  'US Alabama decatur.csv',
#  'US Alabama dora.csv',
#  'US Alabama dothan.csv',
#  'US Alabama enterprise.csv',
#  'US Alabama eufaula.csv',
#  'US Alabama falkville.csv',
#  'US Alabama florence.csv',
#  'US Alabama fort-payne.csv',
#  'US Alabama gadsden.csv',
#  'US Alabama gardendale.csv',
#  'US Alabama hartselle.csv',
#  'US Alabama harvest.csv',
#  'US Alabama hazel-green.csv',
#  'US Alabama heflin.csv',
#  'US Alabama holly-pond.csv',
#  'US Alabama homewood.csv',
#  'US Alabama hoover.csv',
#  'US Alabama huntsville.csv',
#  'US Alabama irvington.csv',
#  'US Alabama jemison.csv',
#  'US Alabama madison.csv',
#  'US Alabama millbrook.csv',
#  'US Alabama mobile.csv',
#  'US Alabama montgomery.csv',
#  'US Alabama moody.csv',
#  'US Alabama morris.csv',
#  'US Alabama munford.csv',
#  'US Alabama new-hope.csv',
#  'US Alabama northport.csv',
#  'US Alabama notasulga.csv',
#  'US Alabama oneonta.csv',
#  'US Alabama opelika.csv',
#  'US Alabama pelham.csv',
#  'US Alabama pell-city.csv',
#  'US Alabama phenix-city.csv',
#  'US Alabama pinson.csv',
#  'US Alabama prattville.csv',
#  'US Alabama rainsville.csv',
#  'US Alabama robertsdale.csv',
#  'US Alabama semmes.csv',
#  'US Alabama spanish-fort.csv',
#  'US Alabama springville.csv',
#  'US Alabama sylacauga.csv',
#  'US Alabama thomasville.csv',
#  'US Alabama troy.csv',
#  'US Alabama trussville.csv',
#  'US Alabama tuscaloosa.csv',
#  'US Alabama vinemont.csv',
#  'US Alabama wetumpka.csv',
#  'US Alabama winfield.csv',
#  'US Alaska akiachak.csv',
#  'US Alaska anchorage.csv',
#  'US Alaska chugiak.csv',
#  'US Alaska delta-junction.csv',
#  'US Alaska eagle-river.csv',
#  'US Alaska eielson-afb.csv',
#  'US Alaska fairbanks.csv',
#  'US Alaska galena.csv',
#  'US Alaska glennallen.csv',
#  'US Alaska haines.csv',
#  'US Alaska homer.csv',
#  'US Alaska juneau.csv',
#  'US Alaska kenai.csv',
#  'US Alaska ketchikan.csv',
#  'US Alaska kodiak.csv',
#  'US Alaska nikiski.csv',
#  'US Alaska north-pole.csv',
#  'US Alaska palmer.csv',
#  'US Alaska petersburg.csv',
#  'US Alaska saint-marys.csv',
#  'US Alaska savoonga.csv',
#  'US Alaska seward.csv',
#  'US Alaska soldotna.csv',
#  'US Alaska talkeetna.csv',
#  'US Alaska tok.csv',
#  'US Alaska unalaska.csv',
#  'US Alaska valdez.csv',
#  'US Alaska wasilla.csv',
#  'US Alaska wrangell.csv',
#  'US Alaska yakutat.csv',
#  'US Arizona ajo.csv',
#  'US Arizona anthem.csv',
#  'US Arizona apache-junction.csv',
#  'US Arizona avondale.csv',
#  'US Arizona bisbee.csv',
#  'US Arizona buckeye.csv',
#  'US Arizona bullhead-city.csv',
#  'US Arizona casa-grande.csv',
#  'US Arizona cave-creek.csv',
#  'US Arizona chandler.csv',
#  'US Arizona chinle.csv',
#  'US Arizona chino-valley.csv',
#  'US Arizona coolidge.csv',
#  'US Arizona cottonwood.csv',
#  'US Arizona dewey.csv',
#  'US Arizona douglas.csv',
#  'US Arizona el-mirage.csv',
#  'US Arizona eloy.csv',
#  'US Arizona flagstaff.csv',
#  'US Arizona florence.csv',
#  'US Arizona fountain-hills.csv',
#  'US Arizona ganado.csv',
#  'US Arizona gilbert.csv',
#  'US Arizona glendale.csv',
#  'US Arizona goodyear.csv',
#  'US Arizona higley.csv',
#  'US Arizona holbrook.csv',
#  'US Arizona kearny.csv',
#  'US Arizona kingman.csv',
#  'US Arizona lake-havasu-city.csv',
#  'US Arizona lakeside.csv',
#  'US Arizona laveen.csv',
#  'US Arizona litchfield-park.csv',
#  'US Arizona marana.csv',
#  'US Arizona maricopa.csv',
#  'US Arizona mesa.csv',
#  'US Arizona mohave-valley.csv',
#  'US Arizona nogales.csv',
#  'US Arizona paradise-valley.csv',
#  'US Arizona parker.csv',
#  'US Arizona payson.csv',
#  'US Arizona peach-springs.csv',
#  'US Arizona peoria.csv',
#  'US Arizona phoenix.csv',
#  'US Arizona prescott.csv',
#  'US Arizona quartzsite.csv',
#  'US Arizona queen-creek.csv',
#  'US Arizona rio-rico.csv',
#  'US Arizona sahuarita.csv',
#  'US Arizona san-luis.csv',
#  'US Arizona scottsdale.csv',
#  'US Arizona sedona.csv',
#  'US Arizona show-low.csv',
#  'US Arizona sierra-vista.csv',
#  'US Arizona snowflake.csv',
#  'US Arizona superior.csv',
#  'US Arizona surprise.csv',
#  'US Arizona tempe.csv',
#  'US Arizona thatcher.csv',
#  'US Arizona tolleson.csv',
#  'US Arizona tombstone.csv',
#  'US Arizona tsaile.csv',
#  'US Arizona tucson.csv',
#  'US Arizona vail.csv',
#  'US Arizona whiteriver.csv',
#  'US Arizona wickenburg.csv',
#  'US Arizona winslow.csv',
#  'US Arizona yuma.csv',
#  'US Arkansas alma.csv',
#  'US Arkansas alpena.csv',
#  'US Arkansas batesville.csv',
#  'US Arkansas beebe.csv',
#  'US Arkansas benton.csv',
#  'US Arkansas bentonville.csv',
#  'US Arkansas bismarck.csv',
#  'US Arkansas blytheville.csv',
#  'US Arkansas brockwell.csv',
#  'US Arkansas brookland.csv',
#  'US Arkansas bryant.csv',
#  'US Arkansas cabot.csv',
#  'US Arkansas camden.csv',
#  'US Arkansas caraway.csv',
#  'US Arkansas cedarville.csv',
#  'US Arkansas coal-hill.csv',
#  'US Arkansas conway.csv',
#  'US Arkansas crossett.csv',
#  'US Arkansas dover.csv',
#  'US Arkansas el-dorado.csv',
#  'US Arkansas farmington.csv',
#  'US Arkansas fayetteville.csv',
#  'US Arkansas fort-smith.csv',
#  'US Arkansas gillett.csv',
#  'US Arkansas gosnell.csv',
#  'US Arkansas gravette.csv',
#  'US Arkansas greenbrier.csv',
#  'US Arkansas greenwood.csv',
#  'US Arkansas hamburg.csv',
#  'US Arkansas hardy.csv',
#  'US Arkansas harrisburg.csv',
#  'US Arkansas harrison.csv',
#  'US Arkansas heber-springs.csv',
#  'US Arkansas hoxie.csv',
#  'US Arkansas jacksonville.csv',
#  'US Arkansas jonesboro.csv',
#  'US Arkansas lake-village.csv',
#  'US Arkansas little-rock.csv',
#  'US Arkansas magnolia.csv',
#  'US Arkansas marion.csv',
#  'US Arkansas marked-tree.csv',
#  'US Arkansas mayflower.csv',
#  'US Arkansas mcgehee.csv',
#  'US Arkansas mena.csv',
#  'US Arkansas monette.csv',
#  'US Arkansas mountain-home.csv',
#  'US Arkansas newport.csv',
#  'US Arkansas north-little-rock.csv',
#  'US Arkansas paragould.csv',
#  'US Arkansas pearcy.csv',
#  'US Arkansas pine-bluff.csv',
#  'US Arkansas pottsville.csv',
#  'US Arkansas quitman.csv',
#  'US Arkansas rogers.csv',
#  'US Arkansas russellville.csv',
#  'US Arkansas searcy.csv',
#  'US Arkansas sheridan.csv',
#  'US Arkansas springdale.csv',
#  'US Arkansas subiaco.csv',
#  'US Arkansas texarkana.csv',
#  'US Arkansas timbo.csv',
#  'US Arkansas tuckerman.csv',
#  'US Arkansas van-buren.csv',
#  'US Arkansas vilonia.csv',
#  'US Arkansas west-fork.csv',
#  'US Arkansas west-memphis.csv',
#  'US Arkansas white-hall.csv',
#  'US Arkansas wilson.csv',
#  'US California alameda.csv',
#  'US California alhambra.csv',
#  'US California aliso-viejo.csv',
#  'US California anaheim.csv',
#  'US California arcadia.csv',
#  'US California bakersfield.csv',
#  'US California beverly-hills.csv',
#  'US California burbank.csv',
#  'US California castro-valley.csv',
#  'US California cerritos.csv',
#  'US California chula-vista.csv',
#  'US California cupertino.csv',
#  'US California cypress.csv',
#  'US California danville.csv',
#  'US California diamond-bar.csv',
#  'US California el-cajon.csv',
#  'US California el-monte.csv',
#  'US California elk-grove.csv',
#  'US California fountain-valley.csv',
#  'US California fremont.csv',
#  'US California fullerton.csv',
#  'US California garden-grove.csv',
#  'US California glendale.csv',
#  'US California granada-hills.csv',
#  'US California huntington-beach.csv',
#  'US California irvine.csv',
#  'US California la-canada-flintridge.csv',
#  'US California la-crescenta.csv',
#  'US California la-jolla.csv',
#  'US California livermore.csv',
#  'US California los-alamitos.csv',
#  'US California los-angeles.csv',
#  'US California manhattan-beach.csv',
#  'US California milpitas.csv',
#  'US California mission-viejo.csv',
#  'US California modesto.csv',
#  'US California oakland.csv',
#  'US California palo-alto.csv',
#  'US California palos-verdes-estates.csv',
#  'US California pasadena.csv',
#  'US California petaluma.csv',
#  'US California pleasanton.csv',
#  'US California poway.csv',
#  'US California rancho-cucamonga.csv',
#  'US California rancho-palos-verdes.csv',
#  'US California riverside.csv',
#  'US California rosemead.csv',
#  'US California roseville.csv',
#  'US California sacramento.csv',
#  'US California san-diego.csv',
#  'US California san-francisco.csv',
#  'US California san-gabriel.csv',
#  'US California san-jose.csv',
#  'US California san-mateo.csv',
#  'US California san-ramon.csv',
#  'US California santa-ana.csv',
#  'US California santa-monica.csv',
#  'US California santa-rosa.csv',
#  'US California saratoga.csv',
#  'US California studio-city.csv',
#  'US California sunnyvale.csv',
#  'US California temple-city.csv',
#  'US California torrance.csv',
#  'US California union-city.csv',
#  'US California valencia.csv',
#  'US California walnut-creek.csv',
#  'US California walnut.csv',
#  'US California woodland-hills.csv',
#  'US Colorado alamosa.csv',
#  'US Colorado arvada.csv',
#  'US Colorado aspen.csv',
#  'US Colorado ault.csv',
#  'US Colorado aurora.csv',
#  'US Colorado berthoud.csv',
#  'US Colorado boulder.csv',
#  'US Colorado brighton.csv',
#  'US Colorado broomfield.csv',
#  'US Colorado brush.csv',
#  'US Colorado calhan.csv',
#  'US Colorado canon-city.csv',
#  'US Colorado castle-rock.csv',
#  'US Colorado centennial.csv',
#  'US Colorado colorado-springs.csv',
#  'US Colorado commerce-city.csv',
#  'US Colorado conifer.csv',
#  'US Colorado craig.csv',
#  'US Colorado crested-butte.csv',
#  'US Colorado denver.csv',
#  'US Colorado durango.csv',
#  'US Colorado eaton.csv',
#  'US Colorado elizabeth.csv',
#  'US Colorado englewood.csv',
#  'US Colorado erie.csv',
#  'US Colorado estes-park.csv',
#  'US Colorado evergreen.csv',
#  'US Colorado fort-collins.csv',
#  'US Colorado fort-lupton.csv',
#  'US Colorado fountain.csv',
#  'US Colorado frederick.csv',
#  'US Colorado frisco.csv',
#  'US Colorado fruita.csv',
#  'US Colorado golden.csv',
#  'US Colorado granby.csv',
#  'US Colorado grand-junction.csv',
#  'US Colorado greeley.csv',
#  'US Colorado greenwood-village.csv',
#  'US Colorado gunnison.csv',
#  'US Colorado johnstown.csv',
#  'US Colorado la-junta.csv',
#  'US Colorado lafayette.csv',
#  'US Colorado lakewood.csv',
#  'US Colorado lamar.csv',
#  'US Colorado laporte.csv',
#  'US Colorado littleton.csv',
#  'US Colorado longmont.csv',
#  'US Colorado louisville.csv',
#  'US Colorado loveland.csv',
#  'US Colorado manitou-springs.csv',
#  'US Colorado monte-vista.csv',
#  'US Colorado montrose.csv',
#  'US Colorado monument.csv',
#  'US Colorado pagosa-springs.csv',
#  'US Colorado palisade.csv',
#  'US Colorado paonia.csv',
#  'US Colorado parker.csv',
#  'US Colorado pueblo.csv',
#  'US Colorado salida.csv',
#  'US Colorado steamboat-springs.csv',
#  'US Colorado sterling.csv',
#  'US Colorado strasburg.csv',
#  'US Colorado walden.csv',
#  'US Colorado walsenburg.csv',
#  'US Colorado westminster.csv',
#  'US Colorado wheat-ridge.csv',
#  'US Colorado windsor.csv',
#  'US Colorado woodland-park.csv',
#  'US Connecticut avon.csv',
#  'US Connecticut berlin.csv',
#  'US Connecticut bethany.csv',
#  'US Connecticut branford.csv',
#  'US Connecticut bristol.csv',
#  'US Connecticut brookfield.csv',
#  'US Connecticut burlington.csv',
#  'US Connecticut cheshire.csv',
#  'US Connecticut colchester.csv',
#  'US Connecticut danbury.csv',
#  'US Connecticut darien.csv',
#  'US Connecticut durham.csv',
#  'US Connecticut east-hampton.csv',
#  'US Connecticut east-hartford.csv',
#  'US Connecticut east-lyme.csv',
#  'US Connecticut enfield.csv',
#  'US Connecticut fairfield.csv',
#  'US Connecticut farmington.csv',
#  'US Connecticut glastonbury.csv',
#  'US Connecticut greenwich.csv',
#  'US Connecticut guilford.csv',
#  'US Connecticut hamden.csv',
#  'US Connecticut hartford.csv',
#  'US Connecticut hebron.csv',
#  'US Connecticut litchfield.csv',
#  'US Connecticut madison.csv',
#  'US Connecticut manchester.csv',
#  'US Connecticut meriden.csv',
#  'US Connecticut middletown.csv',
#  'US Connecticut milford.csv',
#  'US Connecticut monroe.csv',
#  'US Connecticut new-britain.csv',
#  'US Connecticut new-canaan.csv',
#  'US Connecticut new-fairfield.csv',
#  'US Connecticut new-haven.csv',
#  'US Connecticut new-milford.csv',
#  'US Connecticut newington.csv',
#  'US Connecticut newtown.csv',
#  'US Connecticut north-branford.csv',
#  'US Connecticut north-haven.csv',
#  'US Connecticut norwalk.csv',
#  'US Connecticut norwich.csv',
#  'US Connecticut plantsville.csv',
#  'US Connecticut ridgefield.csv',
#  'US Connecticut riverside.csv',
#  'US Connecticut sandy-hook.csv',
#  'US Connecticut shelton.csv',
#  'US Connecticut simsbury.csv',
#  'US Connecticut south-windsor.csv',
#  'US Connecticut southbury.csv',
#  'US Connecticut southington.csv',
#  'US Connecticut stamford.csv',
#  'US Connecticut stratford.csv',
#  'US Connecticut torrington.csv',
#  'US Connecticut trumbull.csv',
#  'US Connecticut wallingford.csv',
#  'US Connecticut waterbury.csv',
#  'US Connecticut west-hartford.csv',
#  'US Connecticut west-haven.csv',
#  'US Connecticut weston.csv',
#  'US Connecticut westport.csv',
#  'US Connecticut wethersfield.csv',
#  'US Connecticut wilton.csv',
#  'US Connecticut windsor.csv',
#  'US Connecticut winsted.csv',
#  'US Connecticut wolcott.csv',
#  'US Connecticut woodbridge.csv',
#  'US Connecticut woodbury.csv',
#  'US DC washington.csv',
#  'US Delaware bear.csv',
#  'US Delaware bridgeville.csv',
#  'US Delaware claymont.csv',
#  'US Delaware delaware-city.csv',
#  'US Delaware delmar.csv',
#  'US Delaware dover.csv',
#  'US Delaware felton.csv',
#  'US Delaware frankford.csv',
#  'US Delaware georgetown.csv',
#  'US Delaware harrington.csv',
#  'US Delaware hockessin.csv',
#  'US Delaware laurel.csv',
#  'US Delaware lewes.csv',
#  'US Delaware middletown.csv',
#  'US Delaware milford.csv',
#  'US Delaware millsboro.csv',
#  'US Delaware milton.csv',
#  'US Delaware new-castle.csv',
#  'US Delaware newark.csv',
#  'US Delaware seaford.csv',
#  'US Delaware selbyville.csv',
#  'US Delaware smyrna.csv',
#  'US Delaware wilmington.csv',
#  'US Delaware woodside.csv',
#  'US Florida altamonte-springs.csv',
#  'US Florida apopka.csv',
#  'US Florida boca-raton.csv',
#  'US Florida boynton-beach.csv',
#  'US Florida bradenton.csv',
#  'US Florida brandon.csv',
#  'US Florida brooksville.csv',
#  'US Florida cape-coral.csv',
#  'US Florida clearwater.csv',
#  'US Florida coral-gables.csv',
#  'US Florida coral-springs.csv',
#  'US Florida davie.csv',
#  'US Florida daytona-beach.csv',
#  'US Florida deland.csv',
#  'US Florida delray-beach.csv',
#  'US Florida deltona.csv',
#  'US Florida fort-lauderdale.csv',
#  'US Florida gainesville.csv',
#  'US Florida hialeah.csv',
#  'US Florida hollywood.csv',
#  'US Florida jacksonville.csv',
#  'US Florida jupiter.csv',
#  'US Florida kissimmee.csv',
#  'US Florida lake-mary.csv',
#  'US Florida lake-worth.csv',
#  'US Florida lakeland.csv',
#  'US Florida largo.csv',
#  'US Florida lithia.csv',
#  'US Florida longwood.csv',
#  'US Florida lutz.csv',
#  'US Florida melbourne.csv',
#  'US Florida miami-beach.csv',
#  'US Florida miami.csv',
#  'US Florida naples.csv',
#  'US Florida new-port-richey.csv',
#  'US Florida ocala.csv',
#  'US Florida orange-park.csv',
#  'US Florida orlando.csv',
#  'US Florida osprey.csv',
#  'US Florida oviedo.csv',
#  'US Florida palm-beach-gardens.csv',
#  'US Florida palm-harbor.csv',
#  'US Florida pembroke-pines.csv',
#  'US Florida pensacola.csv',
#  'US Florida plant-city.csv',
#  'US Florida pompano-beach.csv',
#  'US Florida port-charlotte.csv',
#  'US Florida port-orange.csv',
#  'US Florida punta-gorda.csv',
#  'US Florida safety-harbor.csv',
#  'US Florida sanford.csv',
#  'US Florida sarasota.csv',
#  'US Florida satellite-beach.csv',
#  'US Florida seffner.csv',
#  'US Florida seminole.csv',
#  'US Florida stuart.csv',
#  'US Florida tallahassee.csv',
#  'US Florida tamarac.csv',
#  'US Florida tampa.csv',
#  'US Florida tarpon-springs.csv',
#  'US Florida valrico.csv',
#  'US Florida venice.csv',
#  'US Florida vero-beach.csv',
#  'US Florida west-palm-beach.csv',
#  'US Florida weston.csv',
#  'US Florida winter-garden.csv',
#  'US Florida winter-park.csv',
#  'US Florida winter-springs.csv',
#  'US Georgia acworth.csv',
#  'US Georgia albany.csv',
#  'US Georgia alpharetta.csv',
#  'US Georgia athens.csv',
#  'US Georgia atlanta.csv',
#  'US Georgia augusta.csv',
#  'US Georgia bonaire.csv',
#  'US Georgia brunswick.csv',
#  'US Georgia buford.csv',
#  'US Georgia canton.csv',
#  'US Georgia carrollton.csv',
#  'US Georgia cartersville.csv',
#  'US Georgia cedartown.csv',
#  'US Georgia chamblee.csv',
#  'US Georgia cochran.csv',
#  'US Georgia college-park.csv',
#  'US Georgia columbus.csv',
#  'US Georgia conyers.csv',
#  'US Georgia covington.csv',
#  'US Georgia cumming.csv',
#  'US Georgia dacula.csv',
#  'US Georgia dallas.csv',
#  'US Georgia dalton.csv',
#  'US Georgia decatur.csv',
#  'US Georgia douglasville.csv',
#  'US Georgia duluth.csv',
#  'US Georgia dunwoody.csv',
#  'US Georgia evans.csv',
#  'US Georgia fayetteville.csv',
#  'US Georgia flowery-branch.csv',
#  'US Georgia forsyth.csv',
#  'US Georgia fort-valley.csv',
#  'US Georgia gainesville.csv',
#  'US Georgia griffin.csv',
#  'US Georgia hinesville.csv',
#  'US Georgia hoschton.csv',
#  'US Georgia kennesaw.csv',
#  'US Georgia kingsland.csv',
#  'US Georgia lawrenceville.csv',
#  'US Georgia lilburn.csv',
#  'US Georgia lithia-springs.csv',
#  'US Georgia locust-grove.csv',
#  'US Georgia loganville.csv',
#  'US Georgia macon.csv',
#  'US Georgia marietta.csv',
#  'US Georgia mcdonough.csv',
#  'US Georgia newnan.csv',
#  'US Georgia norcross.csv',
#  'US Georgia peachtree-city.csv',
#  'US Georgia powder-springs.csv',
#  'US Georgia ringgold.csv',
#  'US Georgia rome.csv',
#  'US Georgia rossville.csv',
#  'US Georgia roswell.csv',
#  'US Georgia savannah.csv',
#  'US Georgia sharpsburg.csv',
#  'US Georgia smyrna.csv',
#  'US Georgia snellville.csv',
#  'US Georgia stockbridge.csv',
#  'US Georgia stone-mountain.csv',
#  'US Georgia suwanee.csv',
#  'US Georgia tucker.csv',
#  'US Georgia valdosta.csv',
#  'US Georgia warner-robins.csv',
#  'US Georgia watkinsville.csv',
#  'US Georgia winder.csv',
#  'US Georgia woodstock.csv',
#  'US Georgia zebulon.csv',
#  'US Hawaii aiea.csv',
#  'US Hawaii ewa-beach.csv',
#  'US Hawaii hilo.csv',
#  'US Hawaii honokaa.csv',
#  'US Hawaii honolulu.csv',
#  'US Hawaii kahuku.csv',
#  'US Hawaii kahului.csv',
#  'US Hawaii kailua.csv',
#  'US Hawaii kamuela.csv',
#  'US Hawaii kaneohe.csv',
#  'US Hawaii kapaa.csv',
#  'US Hawaii kapaau.csv',
#  'US Hawaii kapolei.csv',
#  'US Hawaii keaau.csv',
#  'US Hawaii kealakekua.csv',
#  'US Hawaii kihei.csv',
#  'US Hawaii lahaina.csv',
#  'US Hawaii laie.csv',
#  'US Hawaii lanai-city.csv',
#  'US Hawaii lihue.csv',
#  'US Hawaii makawao.csv',
#  'US Hawaii mililani.csv',
#  'US Hawaii pearl-city.csv',
#  'US Hawaii pukalani.csv',
#  'US Hawaii wahiawa.csv',
#  'US Hawaii waianae.csv',
#  'US Hawaii wailuku.csv',
#  'US Hawaii waimea.csv',
#  'US Hawaii waipahu.csv',
#  'US Idaho aberdeen.csv',
#  'US Idaho ashton.csv',
#  'US Idaho blackfoot.csv',
#  'US Idaho boise.csv',
#  'US Idaho caldwell.csv',
#  'US Idaho castleford.csv',
#  'US Idaho coeur-d-alene.csv',
#  'US Idaho driggs.csv',
#  'US Idaho eagle.csv',
#  'US Idaho emmett.csv',
#  'US Idaho filer.csv',
#  'US Idaho hagerman.csv',
#  'US Idaho hailey.csv',
#  'US Idaho idaho-falls.csv',
#  'US Idaho kamiah.csv',
#  'US Idaho kellogg.csv',
#  'US Idaho kuna.csv',
#  'US Idaho lewiston.csv',
#  'US Idaho mccall.csv',
#  'US Idaho meridian.csv',
#  'US Idaho moscow.csv',
#  'US Idaho mountain-home.csv',
#  'US Idaho nampa.csv',
#  'US Idaho new-plymouth.csv',
#  'US Idaho parma.csv',
#  'US Idaho pocatello.csv',
#  'US Idaho post-falls.csv',
#  'US Idaho potlatch.csv',
#  'US Idaho preston.csv',
#  'US Idaho rathdrum.csv',
#  'US Idaho rexburg.csv',
#  'US Idaho rockland.csv',
#  'US Idaho saint-anthony.csv',
#  'US Idaho sandpoint.csv',
#  'US Idaho shelley.csv',
#  'US Idaho soda-springs.csv',
#  'US Idaho spirit-lake.csv',
#  'US Idaho sugar-city.csv',
#  'US Idaho terreton.csv',
#  'US Idaho twin-falls.csv',
#  'US Idaho wallace.csv',
#  'US Idaho weiser.csv',
#  'US Illinois addison.csv',
#  'US Illinois algonquin.csv',
#  'US Illinois arlington-heights.csv',
#  'US Illinois aurora.csv',
#  'US Illinois barrington.csv',
#  'US Illinois bartlett.csv',
#  'US Illinois batavia.csv',
#  'US Illinois buffalo-grove.csv',
#  'US Illinois carbondale.csv',
#  'US Illinois carol-stream.csv',
#  'US Illinois chicago.csv',
#  'US Illinois crystal-lake.csv',
#  'US Illinois darien.csv',
#  'US Illinois deerfield.csv',
#  'US Illinois des-plaines.csv',
#  'US Illinois downers-grove.csv',
#  'US Illinois edwardsville.csv',
#  'US Illinois elk-grove-village.csv',
#  'US Illinois elmhurst.csv',
#  'US Illinois evanston.csv',
#  'US Illinois frankfort.csv',
#  'US Illinois geneva.csv',
#  'US Illinois glen-ellyn.csv',
#  'US Illinois glencoe.csv',
#  'US Illinois glenview.csv',
#  'US Illinois grayslake.csv',
#  'US Illinois gurnee.csv',
#  'US Illinois highland-park.csv',
#  'US Illinois hinsdale.csv',
#  'US Illinois hoffman-estates.csv',
#  'US Illinois joliet.csv',
#  'US Illinois la-grange.csv',
#  'US Illinois lake-forest.csv',
#  'US Illinois lake-zurich.csv',
#  'US Illinois libertyville.csv',
#  'US Illinois lincolnshire.csv',
#  'US Illinois lincolnwood.csv',
#  'US Illinois lisle.csv',
#  'US Illinois lombard.csv',
#  'US Illinois mount-prospect.csv',
#  'US Illinois mundelein.csv',
#  'US Illinois naperville.csv',
#  'US Illinois new-lenox.csv',
#  'US Illinois niles.csv',
#  'US Illinois northbrook.csv',
#  'US Illinois o-fallon.csv',
#  'US Illinois oak-lawn.csv',
#  'US Illinois oak-park.csv',
#  'US Illinois orland-park.csv',
#  'US Illinois oswego.csv',
#  'US Illinois palatine.csv',
#  'US Illinois park-ridge.csv',
#  'US Illinois peoria.csv',
#  'US Illinois plainfield.csv',
#  'US Illinois rockford.csv',
#  'US Illinois rolling-meadows.csv',
#  'US Illinois roselle.csv',
#  'US Illinois saint-charles.csv',
#  'US Illinois schaumburg.csv',
#  'US Illinois skokie.csv',
#  'US Illinois tinley-park.csv',
#  'US Illinois vernon-hills.csv',
#  'US Illinois villa-park.csv',
#  'US Illinois wheaton.csv',
#  'US Illinois wheeling.csv',
#  'US Illinois williamsville.csv',
#  'US Illinois wilmette.csv',
#  'US Illinois winnetka.csv',
#  'US Indiana albion.csv',
#  'US Indiana alexandria.csv',
#  'US Indiana angola.csv',
#  'US Indiana avon.csv',
#  'US Indiana bloomington.csv',
#  'US Indiana brazil.csv',
#  'US Indiana brookville.csv',
#  'US Indiana brownsburg.csv',
#  'US Indiana brownstown.csv',
#  'US Indiana bunker-hill.csv',
#  'US Indiana carmel.csv',
#  'US Indiana chesterton.csv',
#  'US Indiana columbus.csv',
#  'US Indiana crawfordsville.csv',
#  'US Indiana crown-point.csv',
#  'US Indiana dyer.csv',
#  'US Indiana elkhart.csv',
#  'US Indiana evansville.csv',
#  'US Indiana fishers.csv',
#  'US Indiana fort-branch.csv',
#  'US Indiana fort-wayne.csv',
#  'US Indiana franklin.csv',
#  'US Indiana goshen.csv',
#  'US Indiana granger.csv',
#  'US Indiana greenfield.csv',
#  'US Indiana greensburg.csv',
#  'US Indiana greenwood.csv',
#  'US Indiana hammond.csv',
#  'US Indiana highland.csv',
#  'US Indiana hobart.csv',
#  'US Indiana indianapolis.csv',
#  'US Indiana jeffersonville.csv',
#  'US Indiana kokomo.csv',
#  'US Indiana lafayette.csv',
#  'US Indiana laporte.csv',
#  'US Indiana marion.csv',
#  'US Indiana merrillville.csv',
#  'US Indiana michigan-city.csv',
#  'US Indiana middlebury.csv',
#  'US Indiana mishawaka.csv',
#  'US Indiana mooresville.csv',
#  'US Indiana muncie.csv',
#  'US Indiana munster.csv',
#  'US Indiana nappanee.csv',
#  'US Indiana new-albany.csv',
#  'US Indiana new-carlisle.csv',
#  'US Indiana new-palestine.csv',
#  'US Indiana newburgh.csv',
#  'US Indiana noblesville.csv',
#  'US Indiana ossian.csv',
#  'US Indiana plymouth.csv',
#  'US Indiana portage.csv',
#  'US Indiana princeton.csv',
#  'US Indiana rossville.csv',
#  'US Indiana russiaville.csv',
#  'US Indiana saint-john.csv',
#  'US Indiana schererville.csv',
#  'US Indiana sellersburg.csv',
#  'US Indiana seymour.csv',
#  'US Indiana south-bend.csv',
#  'US Indiana south-whitley.csv',
#  'US Indiana tell-city.csv',
#  'US Indiana terre-haute.csv',
#  'US Indiana valparaiso.csv',
#  'US Indiana west-lafayette.csv',
#  'US Indiana westfield.csv',
#  'US Indiana yorktown.csv',
#  'US Indiana zionsville.csv',
#  'US Iowa alburnett.csv',
#  'US Iowa ames.csv',
#  'US Iowa anamosa.csv',
#  'US Iowa ankeny.csv',
#  'US Iowa audubon.csv',
#  'US Iowa avoca.csv',
#  'US Iowa bettendorf.csv',
#  'US Iowa burlington.csv',
#  'US Iowa cedar-falls.csv',
#  'US Iowa cedar-rapids.csv',
#  'US Iowa charles-city.csv',
#  'US Iowa clear-lake.csv',
#  'US Iowa clinton.csv',
#  'US Iowa coralville.csv',
#  'US Iowa council-bluffs.csv',
#  'US Iowa davenport.csv',
#  'US Iowa decorah.csv',
#  'US Iowa delhi.csv',
#  'US Iowa des-moines.csv',
#  'US Iowa dike.csv',
#  'US Iowa dubuque.csv',
#  'US Iowa eldridge.csv',
#  'US Iowa fairbank.csv',
#  'US Iowa fairfield.csv',
#  'US Iowa fort-dodge.csv',
#  'US Iowa fort-madison.csv',
#  'US Iowa gilbert.csv',
#  'US Iowa grimes.csv',
#  'US Iowa grinnell.csv',
#  'US Iowa harlan.csv',
#  'US Iowa hudson.csv',
#  'US Iowa humboldt.csv',
#  'US Iowa independence.csv',
#  'US Iowa indianola.csv',
#  'US Iowa iowa-city.csv',
#  'US Iowa jefferson.csv',
#  'US Iowa johnston.csv',
#  'US Iowa la-porte-city.csv',
#  'US Iowa lawton.csv',
#  'US Iowa lost-nation.csv',
#  'US Iowa malvern.csv',
#  'US Iowa marion.csv',
#  'US Iowa marshalltown.csv',
#  'US Iowa mason-city.csv',
#  'US Iowa maynard.csv',
#  'US Iowa mcgregor.csv',
#  'US Iowa milford.csv',
#  'US Iowa muscatine.csv',
#  'US Iowa nevada.csv',
#  'US Iowa new-hampton.csv',
#  'US Iowa north-liberty.csv',
#  'US Iowa oelwein.csv',
#  'US Iowa ottumwa.csv',
#  'US Iowa parkersburg.csv',
#  'US Iowa runnells.csv',
#  'US Iowa sioux-city.csv',
#  'US Iowa sumner.csv',
#  'US Iowa tiffin.csv',
#  'US Iowa traer.csv',
#  'US Iowa urbandale.csv',
#  'US Iowa van-horne.csv',
#  'US Iowa waterloo.csv',
#  'US Iowa waukee.csv',
#  'US Iowa waverly.csv',
#  'US Iowa west-des-moines.csv',
#  'US Iowa west-liberty.csv',
#  'US Iowa west-union.csv',
#  'US Iowa winfield.csv',
#  'US Kansas abilene.csv',
#  'US Kansas andover.csv',
#  'US Kansas atchison.csv',
#  'US Kansas atwood.csv',
#  'US Kansas augusta.csv',
#  'US Kansas baldwin-city.csv',
#  'US Kansas basehor.csv',
#  'US Kansas beloit.csv',
#  'US Kansas bonner-springs.csv',
#  'US Kansas buhler.csv',
#  'US Kansas chanute.csv',
#  'US Kansas chetopa.csv',
#  'US Kansas clearwater.csv',
#  'US Kansas columbus.csv',
#  'US Kansas concordia.csv',
#  'US Kansas de-soto.csv',
#  'US Kansas derby.csv',
#  'US Kansas dodge-city.csv',
#  'US Kansas el-dorado.csv',
#  'US Kansas elbing.csv',
#  'US Kansas emporia.csv',
#  'US Kansas eudora.csv',
#  'US Kansas fort-leavenworth.csv',
#  'US Kansas garden-city.csv',
#  'US Kansas gardner.csv',
#  'US Kansas garnett.csv',
#  'US Kansas girard.csv',
#  'US Kansas goddard.csv',
#  'US Kansas goodland.csv',
#  'US Kansas haysville.csv',
#  'US Kansas holton.csv',
#  'US Kansas hutchinson.csv',
#  'US Kansas junction-city.csv',
#  'US Kansas kansas-city.csv',
#  'US Kansas lansing.csv',
#  'US Kansas larned.csv',
#  'US Kansas lawrence.csv',
#  'US Kansas leavenworth.csv',
#  'US Kansas leawood.csv',
#  'US Kansas lenexa.csv',
#  'US Kansas leon.csv',
#  'US Kansas liberal.csv',
#  'US Kansas maize.csv',
#  'US Kansas manhattan.csv',
#  'US Kansas mcpherson.csv',
#  'US Kansas melvern.csv',
#  'US Kansas minneapolis.csv',
#  'US Kansas mulvane.csv',
#  'US Kansas newton.csv',
#  'US Kansas olathe.csv',
#  'US Kansas overland-park.csv',
#  'US Kansas paola.csv',
#  'US Kansas pittsburg.csv',
#  'US Kansas pomona.csv',
#  'US Kansas prairie-village.csv',
#  'US Kansas rose-hill.csv',
#  'US Kansas salina.csv',
#  'US Kansas scott-city.csv',
#  'US Kansas shawnee-mission.csv',
#  'US Kansas shawnee.csv',
#  'US Kansas spring-hill.csv',
#  'US Kansas stilwell.csv',
#  'US Kansas tecumseh.csv',
#  'US Kansas topeka.csv',
#  'US Kansas towanda.csv',
#  'US Kansas valley-center.csv',
#  'US Kansas wichita.csv',
#  'US Kansas winfield.csv',
#  'US Kentucky alexandria.csv',
#  'US Kentucky ashland.csv',
#  'US Kentucky bardstown.csv',
#  'US Kentucky bellevue.csv',
#  'US Kentucky benton.csv',
#  'US Kentucky bowling-green.csv',
#  'US Kentucky brandenburg.csv',
#  'US Kentucky buckner.csv',
#  'US Kentucky carlisle.csv',
#  'US Kentucky cecilia.csv',
#  'US Kentucky corbin.csv',
#  'US Kentucky covington.csv',
#  'US Kentucky crestwood.csv',
#  'US Kentucky danville.csv',
#  'US Kentucky dayton.csv',
#  'US Kentucky dry-ridge.csv',
#  'US Kentucky eastern.csv',
#  'US Kentucky elizabethtown.csv',
#  'US Kentucky erlanger.csv',
#  'US Kentucky florence.csv',
#  'US Kentucky fort-thomas.csv',
#  'US Kentucky frankfort.csv',
#  'US Kentucky franklin.csv',
#  'US Kentucky ft-mitchell.csv',
#  'US Kentucky georgetown.csv',
#  'US Kentucky grayson.csv',
#  'US Kentucky greenup.csv',
#  'US Kentucky harrodsburg.csv',
#  'US Kentucky hebron.csv',
#  'US Kentucky henderson.csv',
#  'US Kentucky hodgenville.csv',
#  'US Kentucky hopkinsville.csv',
#  'US Kentucky independence.csv',
#  'US Kentucky inez.csv',
#  'US Kentucky irvine.csv',
#  'US Kentucky lawrenceburg.csv',
#  'US Kentucky lewisport.csv',
#  'US Kentucky lexington.csv',
#  'US Kentucky london.csv',
#  'US Kentucky louisa.csv',
#  'US Kentucky louisville.csv',
#  'US Kentucky madisonville.csv',
#  'US Kentucky manchester.csv',
#  'US Kentucky mayfield.csv',
#  'US Kentucky maysville.csv',
#  'US Kentucky middlesboro.csv',
#  'US Kentucky monticello.csv',
#  'US Kentucky nicholasville.csv',
#  'US Kentucky nortonville.csv',
#  'US Kentucky owensboro.csv',
#  'US Kentucky owingsville.csv',
#  'US Kentucky paducah.csv',
#  'US Kentucky paintsville.csv',
#  'US Kentucky paris.csv',
#  'US Kentucky princeton.csv',
#  'US Kentucky radcliff.csv',
#  'US Kentucky richmond.csv',
#  'US Kentucky russell.csv',
#  ...]
